# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="B7MPetTpYy1FzAPumCR6")
project = rf.workspace("1-btccx").project("cat-breeds-2oxx4")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cat-breeds-5 in yolov11:: 100%|██████████| 7708/7708 [00:02<00:00, 3704.17it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.40-py3-none-any.whl.metadata (35 kB)
# ...
#   Using cached ultralytics_thop-2.0.12-py3-none-any.whl.metadata (9.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train data=/content/cat-breeds-5/data.yaml model=yolov8n.pt epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...
